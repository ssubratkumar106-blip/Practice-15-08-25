# %% [markdown]
# <a href="https://colab.research.google.com/github/ssubratkumar106-blip/Practice-15-08-25/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/tmp/customer_churn.csv')
display(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2442216611.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('/tmp/customer_churn.csv')
#       2 display(df.head())
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
csv_data = """customerID,gender,SeniorCitizen,Partner,Dependents,tenure,PhoneService,MultipleLines,InternetService,OnlineSecurity,OnlineBackup,DeviceProtection,TechSupport,StreamingTV,StreamingMovies,Contract,PaperlessBilling,PaymentMethod,MonthlyCharges,TotalCharges,Churn
7590-VHVEG,Female,0,Yes,No,1,No,No phone service,DSL,No,Yes,No,No,No,No,Month-to-month,Yes,Electronic check,29.85,29.85,No
5575-GNVDE,Male,0,No,No,34,Yes,No,DSL,Yes,No,Yes,No,No,No,One year,No,Mailed check,56.95,1889.5,No
3668-QPYBK,Male,0,No,No,2,Yes,No,DSL,Yes,Yes,No,No,No,No,Month-to-month,Yes,Mailed check,53.85,108.15,Yes
7795-CFOCW,Male,0,No,No,45,No,No phone service,DSL,Yes,No,Yes,Yes,No,No,One year,No,Bank transfer (automatic),42.3,1840.75,No
9237-HQITU,Female,0,No,No,2,Yes,No,Fiber optic,No,No,No,No,No,No,Month-to-month,Yes,Electronic check,70.7,151.65,Yes
9305-CDSKC,Female,0,No,No,8,Yes,Yes,Fiber optic,No,No,Yes,No,Yes,Yes,Month-to-month,Yes,Electronic check,99.65,820.5,Yes
1452-KIOVK,Male,0,No,Yes,22,Yes,Yes,Fiber optic,No,Yes,No,No,Yes,No,Month-to-month,Yes,Credit card (automatic),89.1,1949.4,No
6713-OKOMC,Female,0,No,No,10,No,No phone service,DSL,Yes,No,No,No,No,No,Month-to-month,No,Mailed check,29.75,301.9,No
7892-POOKP,Female,0,Yes,No,28,Yes,Yes,Fiber optic,No,No,Yes,Yes,Yes,Yes,Month-to-month,Yes,Electronic check,104.8,3046.05,Yes
6388-TABGU,Male,0,No,Yes,62,Yes,No,DSL,Yes,Yes,No,No,No,No,One year,No,Bank transfer (automatic),56.15,3487.95,No
9763-GRSKD,Male,0,Yes,Yes,13,Yes,No,DSL,Yes,No,No,No,No,No,Month-to-month,Yes,Mailed check,49.95,587.45,No
7469-LKBCI,Male,0,No,No,16,Yes,No,No,No internet service,No internet service,No internet service,No internet service,No internet service,No internet service,Two year,No,Credit card (automatic),18.95,326.8,No
8091-TTVAX,Male,0,Yes,No,58,Yes,Yes,Fiber optic,No,No,Yes,No,Yes,Yes,One year,No,Credit card (automatic),100.35,5681.1,No
0280-XJGEX,Male,0,No,No,49,Yes,Yes,Fiber optic,No,Yes,Yes,No,Yes,Yes,Month-to-month,Yes,Bank transfer (automatic),103.7,5036.3,
"""

with open('/tmp/customer_churn.csv', 'w') as f:
    f.write(csv_data)

# %%
display(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-6478081.py in <cell line: 0>()
# ----> 1 display(df.head())
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv('/tmp/customer_churn.csv')
display(df.head())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.Churn.value_counts()
# Out:
# Churn
# No     9
# Yes    4
# Name: count, dtype: int64

# %%
517400/df.shape[0]
# Out:
# 36957.142857142855

# %%
df.drop('customerID',axis='columns',inplace=True)

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df.TotalCharges.values
# Out:
# array([  29.85, 1889.5 ,  108.15, 1840.75,  151.65,  820.5 , 1949.4 ,
#         301.9 , 3046.05, 3487.95,  587.45,  326.8 , 5681.1 , 5036.3 ])

# %%
pd.to_numeric(df.TotalCharges,errors='coerce').isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# Name: TotalCharges, dtype: bool

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
# Empty DataFrame
# Columns: [gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []

# %%
df.shape
# Out:
# (14, 20)

# %%
df.iloc[13].TotalCharges
# Out:
# np.float64(5036.3)

# %%
df[df.TotalCharges!=' '].shape
# Out:
# (14, 20)

# %%
df1 = df[df.TotalCharges!=' ']
df1.shape
# Out:
# (14, 20)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df1.TotalCharges = pd.to_numeric(df1.TotalCharges)

# %%
df1.TotalCharges.values
# Out:
# array([  29.85, 1889.5 ,  108.15, 1840.75,  151.65,  820.5 , 1949.4 ,
#         301.9 , 3046.05, 3487.95,  587.45,  326.8 , 5681.1 , 5036.3 ])

# %%
df1[df1.Churn=='No']
# Out:
#     gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   Female              0     Yes         No       1           No
# 1     Male              0      No         No      34          Yes
# 3     Male              0      No         No      45           No
# 6     Male              0      No        Yes      22          Yes
# 7   Female              0      No         No      10           No
# 9     Male              0      No        Yes      62          Yes
# 10    Male              0     Yes        Yes      13          Yes
# 11    Male              0      No         No      16          Yes
# 12    Male              0     Yes         No      58          Yes
#
#        MultipleLines InternetService       OnlineSecurity  \
# 0   No phone service             DSL                   No
# 1                 No             DSL                  Yes
# 3   No phone service             DSL                  Yes
# 6                Yes     Fiber optic                   No
# ...

# %%
tenure_churn_no = df1[df1.Churn=='No'].tenure
tenure_churn_yes = df1[df1.Churn=='Yes'].tenure

plt.xlabel("tenure")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist([tenure_churn_yes, tenure_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
mc_churn_no = df1[df1.Churn=='No'].MonthlyCharges
mc_churn_yes = df1[df1.Churn=='Yes'].MonthlyCharges

plt.xlabel("Monthly Charges")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist([mc_churn_yes, mc_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
def print_unique_col_values(df):
       for column in df:
            if df[column].dtypes=='object':
                print(f'{column}: {df[column].unique()}')

# %%
print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes' nan]

# %%
df1.replace('No internet service','No',inplace=True)
df1.replace('No phone service','No',inplace=True)

# %%
print_unique_col_values(df1)

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    df1[col].replace({'Yes': 1,'No': 0},inplace=True)

# %%
for col in df1:
    print(f'{col}: {df1[col].unique()}')
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [ 29.85  56.95  53.85  42.3   70.7   99.65  89.1   29.75 104.8   56.15
#   49.95  18.95 100.35 103.7 ]
# TotalCharges: [  29.85 1889.5   108.15 1840.75  151.65  820.5  1949.4   301.9  3046.05
#  3487.95  587.45  326.8  5681.1  5036.3 ]
# Churn: [ 0.  1. nan]

# %%
df1['gender'].replace({'Female':1,'Male':0},inplace=True)

# %%
df1.gender.unique()
# Out:
# array([1, 0])

# %%
df2 = pd.get_dummies(data=df1, columns=['InternetService','Contract','PaymentMethod'])
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.sample(5)
# Out:
#     gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 11       0              0        0           0      16             1
# 4        1              0        0           0       2             1
# 6        0              0        0           1      22             1
# 1        0              0        0           0      34             1
# 8        1              0        1           0      28             1
#
#     MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 11              0               0             0                 0  ...
# 4               0               0             0                 0  ...
# 6               1               0             1                 0  ...
# 1               0               1             0                 1  ...
# 8               1               0             0                 1  ...
#
#     InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# ...

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                      float64
# InternetService_DSL                           bool
# ...

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
for col in df2:
    print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.54098361 0.01639344 0.72131148 0.1147541  0.3442623
#  0.14754098 0.44262295 1.         0.19672131 0.24590164 0.93442623
#  0.78688525]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [0.12696564 0.4426325  0.40652301 0.27198602 0.60279557 0.94001165
#  0.81712289 0.12580082 1.         0.43331392 0.36109493 0.
#  0.9481654  0.98718695]
# TotalCharges: [0.         0.32906879 0.01385534 0.32044238 0.02155275 0.1399071
#  0.33966821 0.04813979 0.53372263 0.61191772 0.09866844 0.0525459
#  1.         0.88590135]
# Churn: [ 0.  1. nan]
# InternetService_DSL: [ True False]
# InternetService_Fiber optic: [False  True]
# InternetService_No: [False  True]
# Contract_Month-to-month: [ True False]
# ...

# %%
df2.dropna(subset=['Churn'], inplace=True)

X = df2.drop('Churn',axis='columns')
y = testLabels = df2.Churn.astype(np.float32)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
y_train.value_counts()
# Out:
# Churn
# 0.0    7
# 1.0    3
# Name: count, dtype: int64

# %%
y.value_counts()
# Out:
# Churn
# 0.0    9
# 1.0    4
# Name: count, dtype: int64

# %%
5163/1869
# Out:
# 2.7624398073836276

# %%
y_test.value_counts()
# Out:
# Churn
# 0.0    2
# 1.0    1
# Name: count, dtype: int64

# %%
X_train.shape
# Out:
# (10, 26)

# %%
X_test.shape
# Out:
# (3, 26)

# %%
X_train[:10]
# Out:
#     gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 5        1              0        0           0  0.114754             1
# 4        1              0        0           0  0.016393             1
# 11       0              0        0           0  0.245902             1
# 10       0              0        1           1  0.196721             1
# 6        0              0        0           1  0.344262             1
# 0        1              0        1           0  0.000000             0
# 1        0              0        0           0  0.540984             1
# 7        1              0        0           0  0.147541             0
# 3        0              0        0           0  0.721311             0
# 2        0              0        0           0  0.016393             1
#
#     MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5               1               0             0                 1  ...
# ...

# %%
len(X_train.columns)
# Out:
# 26

# %%
from tensorflow_addons import losses
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-520224345.py in <cell line: 0>()
# ----> 1 from tensorflow_addons import losses
#
# ModuleNotFoundError: No module named 'tensorflow_addons'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install tensorflow-addons
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow-addons (from versions: none)
# ERROR: No matching distribution found for tensorflow-addons

# %% [markdown]
# # Task
# Explain the error in the selected code. If possible, fix the error and incorporate the changes into the existing code. Otherwise, try to diagnose the error. The code uses `tensorflow_addons.losses`.

# %% [markdown]
# ## Identify the desired loss function
#
# ### Subtask:
# Determine which specific loss function from `tensorflow_addons.losses` the user intended to use.

# %% [markdown]
# ## Find or implement an alternative
#
# ### Subtask:
# Although the specific desired loss function from `tensorflow_addons.losses` is not explicitly stated, the context of the notebook suggests a binary classification problem where `tensorflow_addons` might be used for handling class imbalance. We will assume the user intended to use a loss function suitable for imbalanced binary classification. Since `tensorflow_addons` is not available, we will find or implement an alternative loss function within core TensorFlow or Keras that can address class imbalance, such as a weighted binary crossentropy.

# %% [markdown]
# **Reasoning**:
# The `tensorflow-addons` library is not available, as indicated by the installation error. The goal is to use a weighted binary crossentropy loss function from core TensorFlow or Keras to address class imbalance, as the dataset is small and likely imbalanced. I will calculate the class weights based on the training data and then define a weighted binary crossentropy loss function.

# %%
import tensorflow as tf

neg, pos = np.bincount(y_train.astype(int))
total = neg + pos
print('Examples:\n    Total: {}\n      Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))

# Calculate class weights
weight_for_0 = (1 / neg) * (total / 2.0)
weight_for_1 = (1 / pos) * (total / 2.0)

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))

def weighted_binary_crossentropy(y_true, y_pred):
    # Calculate the binary crossentropy loss
    bce = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)

    # Apply class weights
    weight_vector = y_true * weight_for_1 + (1. - y_true) * weight_for_0
    weighted_bce = weight_vector * bce

    # Return the average loss
    return tf.reduce_mean(weighted_bce)
# Out:
# Examples:
#     Total: 10
#       Positive: 3 (30.00% of total)
#
# Weight for class 0: 0.71
# Weight for class 1: 1.67

# %% [markdown]
# ## Replace the import and usage
#
# ### Subtask:
# Modify the code to use the alternative TensorFlow loss function or the newly implemented custom loss function instead of importing from `tensorflow_addons.losses`.

# %% [markdown]
# **Reasoning**:
# Remove the import of tensorflow_addons and use the custom weighted binary crossentropy loss function in the model.

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers

# Define the model
model = keras.Sequential([
    layers.Dense(20, input_shape=(26,), activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# Compile the model using the custom weighted binary crossentropy loss function
model.compile(optimizer='adam',
              loss=weighted_binary_crossentropy,
              metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 20)             │           540 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 561 (2.19 KB)
#  Trainable params: 561 (2.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Reasoning**:
# Train the model using the training data and the custom weighted binary crossentropy loss function.

# %%
model.fit(X_train, y_train, epochs=100, verbose=0)

# %% [markdown]
# **Reasoning**:
# The model has been trained, now evaluate the model on the test set to assess its performance.

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 1.0000 - loss: 0.2276
# [0.22759230434894562, 1.0]

# %% [markdown]
# ## Verify the fix
#
# ### Subtask:
# Verify the fix by examining the model's performance using the evaluation results from the previous subtask.

# %% [markdown]
# **Reasoning**:
# Analyze the output of the model evaluation to determine if the fix was effective.

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 1.0000 - loss: 0.2276
# Test Loss: 0.22759230434894562
# Test Accuracy: 1.0

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The original code likely intended to use a loss function from `tensorflow_addons.losses` for a binary classification problem, potentially to handle class imbalance.
# *   Due to the unavailability of `tensorflow_addons`, a custom `weighted_binary_crossentropy` loss function was implemented using core TensorFlow.
# *   This custom loss function calculates class weights based on the training data distribution and applies them to the standard binary crossentropy loss.
# *   The model was successfully compiled and trained using this custom loss function.
# *   The model achieved a test loss of approximately 0.2276 and a test accuracy of 1.0 after being trained with the custom weighted binary crossentropy loss.
#
# ### Insights or Next Steps
#
# *   The implementation of a weighted loss function successfully addressed the potential need for handling class imbalance without using `tensorflow_addons`.
# *   The high test accuracy of 1.0 might indicate potential overfitting or a very easy dataset. Further analysis with different evaluation metrics (e.g., precision, recall, F1-score) and cross-validation would be beneficial to get a more comprehensive understanding of the model's performance.

# %% [markdown]
# ## Identify the desired loss function
#
# ### Subtask:
# Determine which specific loss function from `tensorflow_addons.losses` the user intended to use.

# %% [markdown]
# ## Find or implement an alternative
#
# ### Subtask:
# Although the specific desired loss function from `tensorflow_addons.losses` is not explicitly stated, the context of the notebook suggests a binary classification problem where `tensorflow_addons` might be used for handling class imbalance. We will assume the user intended to use a loss function suitable for imbalanced binary classification. Since `tensorflow_addons` is not available, we will find or implement an alternative loss function within core TensorFlow or Keras that can address class imbalance, such as a weighted binary crossentropy.

# %% [markdown]
# **Reasoning**:
# The `tensorflow-addons` library is not available, as indicated by the installation error. The goal is to use a weighted binary crossentropy loss function from core TensorFlow or Keras to address class imbalance, as the dataset is small and likely imbalanced. I will calculate the class weights based on the training data and then define a weighted binary crossentropy loss function.

# %%
import tensorflow as tf

neg, pos = np.bincount(y_train.astype(int))
total = neg + pos
print('Examples:\n    Total: {}\n      Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))

# Calculate class weights
weight_for_0 = (1 / neg) * (total / 2.0)
weight_for_1 = (1 / pos) * (total / 2.0)

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))

def weighted_binary_crossentropy(y_true, y_pred):
    # Calculate the binary crossentropy loss
    bce = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)

    # Apply class weights
    weight_vector = y_true * weight_for_1 + (1. - y_true) * weight_for_0
    weighted_bce = weight_vector * bce

    # Return the average loss
    return tf.reduce_mean(weighted_bce)
# Out:
# Examples:
#     Total: 10
#       Positive: 3 (30.00% of total)
#
# Weight for class 0: 0.71
# Weight for class 1: 1.67

# %% [markdown]
# ## Replace the import and usage
#
# ### Subtask:
# Modify the code to use the alternative TensorFlow loss function or the newly implemented custom loss function instead of importing from `tensorflow_addons.losses`.

# %% [markdown]
# **Reasoning**:
# Remove the import of tensorflow_addons and use the custom weighted binary crossentropy loss function in the model.

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers

# Define the model
model = keras.Sequential([
    layers.Dense(20, input_shape=(26,), activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# Compile the model using the custom weighted binary crossentropy loss function
model.compile(optimizer='adam',
              loss=weighted_binary_crossentropy,
              metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 20)             │           540 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 561 (2.19 KB)
#  Trainable params: 561 (2.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import confusion_matrix , classification_report

# %%
def ANN(X_train, y_train, X_test, y_test, loss, weights):
    model = keras.Sequential([
        keras.layers.Dense(26, input_dim=26, activation='relu'),
        keras.layers.Dense(15, activation='relu'),
        keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='adam', loss=loss, metrics=['accuracy'])

    if weights == -1:
        model.fit(X_train, y_train, epochs=100)
    else:
        model.fit(X_train, y_train, epochs=100, class_weight = weights)

    print(model.evaluate(X_test, y_test))

    y_preds = model.predict(X_test)
    y_preds = np.round(y_preds)

    print("Classification Report: \n", classification_report(y_test, y_preds))

    return y_preds

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4000 - loss: 0.7050
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4000 - loss: 0.6971
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4000 - loss: 0.6895
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6000 - loss: 0.6820
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6000 - loss: 0.6747
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6000 - loss: 0.6678
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8000 - loss: 0.6612
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8000 - loss: 0.6551
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8000 - loss: 0.6490
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8000 - loss: 0.6430
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8000 - loss: 0.6370
# Epoch 12/100
# ...

# %%
# Class count
count_class_0, count_class_1 = df1.Churn.value_counts()

# Divide by class
df_class_0 = df2[df2['Churn'] == 0]
df_class_1 = df2[df2['Churn'] == 1]

# %%
# Undersample 0-class and concat the DataFrames of both class
df_class_0_under = df_class_0.sample(count_class_1)
df_test_under = pd.concat([df_class_0_under, df_class_1], axis=0)

print('Random under-sampling:')
print(df_test_under.Churn.value_counts())
# Out:
# Random under-sampling:
# Churn
# 0.0    4
# 1.0    4
# Name: count, dtype: int64

# %%
X = df_test_under.drop('Churn',axis='columns')
y = df_test_under['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
# Number of classes in training Data
y_train.value_counts()
# Out:
# Churn
# 0.0    3
# 1.0    3
# Name: count, dtype: int64

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5000 - loss: 0.7430
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5000 - loss: 0.7224
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.7035
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5000 - loss: 0.6857
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5000 - loss: 0.6688
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5000 - loss: 0.6527
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8333 - loss: 0.6373
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8333 - loss: 0.6237
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8333 - loss: 0.6110
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8333 - loss: 0.5990
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8333 - loss: 0.5880
# Epoch 12/100
# ...

# %%
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_test_over = pd.concat([df_class_0, df_class_1_over], axis=0)

print('Random over-sampling:')
print(df_test_over.Churn.value_counts())
# Out:
# Random over-sampling:
# Churn
# 0.0    9
# 1.0    9
# Name: count, dtype: int64

# %%
X = df_test_over.drop('Churn',axis='columns')
y = df_test_over['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
y_train.value_counts()
# Out:
# Churn
# 1.0    7
# 0.0    7
# Name: count, dtype: int64

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5714 - loss: 0.6639
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6429 - loss: 0.6553
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6429 - loss: 0.6468
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6429 - loss: 0.6384
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6429 - loss: 0.6300
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.6429 - loss: 0.6219
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6429 - loss: 0.6138
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7143 - loss: 0.6057
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7143 - loss: 0.5984
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7143 - loss: 0.5911
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.7857 - loss: 0.5838
# Epoch 12/100
# ...

# %%
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_test_over = pd.concat([df_class_0, df_class_1_over], axis=0)

print('Random over-sampling:')
print(df_test_over.Churn.value_counts())
# Out:
# Random over-sampling:
# Churn
# 0.0    9
# 1.0    9
# Name: count, dtype: int64

# %%
X = df_test_over.drop('Churn',axis='columns')
y = df_test_over['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
y_test.value_counts()
# Out:
# Churn
# 1.0    2
# 0.0    2
# Name: count, dtype: int64

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1429 - loss: 0.7772
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1429 - loss: 0.7647
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.1429 - loss: 0.7524
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.1429 - loss: 0.7405
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1429 - loss: 0.7289
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5000 - loss: 0.7176
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5000 - loss: 0.7066
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.6958
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5000 - loss: 0.6858
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5000 - loss: 0.6763
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5000 - loss: 0.6670
# Epoch 12/100
# ...

# %%
X = df2.drop('Churn',axis='columns')
y = df2['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
X = df2.drop('Churn',axis='columns')
y = df2['Churn']
y.value_counts()
# Out:
# Churn
# 0.0    9
# 1.0    4
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy='minority', k_neighbors=3)
X_sm, y_sm = smote.fit_resample(X, y)

y_sm.value_counts()
# Out:
# Churn
# 0.0    9
# 1.0    9
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_sm, y_sm, test_size=0.2, random_state=15, stratify=y_sm)

# %%
y_train.value_counts()
# Out:
# Churn
# 1.0    7
# 0.0    7
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# Churn
# 1.0    2
# 0.0    2
# Name: count, dtype: int64

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5000 - loss: 0.7971
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.7799
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.7635
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.7476
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5000 - loss: 0.7323
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5000 - loss: 0.7179
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5000 - loss: 0.7042
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5000 - loss: 0.6908
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5714 - loss: 0.6781
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6429 - loss: 0.6659
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5714 - loss: 0.6543
# Epoch 12/100
# ...

# %%
df2.Churn.value_counts()
# Out:
# Churn
# 0.0    9
# 1.0    4
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
y_train.value_counts()
# Out:
# Churn
# 0.0    7
# 1.0    3
# Name: count, dtype: int64

# %%
df3 = X_train.copy()
df3['Churn'] = y_train

# %%
df3.head()
# Out:
#     gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 5        1              0        0           0  0.114754             1
# 4        1              0        0           0  0.016393             1
# 11       0              0        0           0  0.245902             1
# 10       0              0        1           1  0.196721             1
# 6        0              0        0           1  0.344262             1
#
#     MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5               1               0             0                 1  ...
# 4               0               0             0                 0  ...
# 11              0               0             0                 0  ...
# 10              0               1             0                 0  ...
# 6               1               0             1                 0  ...
#
#     InternetService_Fiber optic  InternetService_No  Contract_Month-to-month  \
# ...

# %%
4130/3
# Out:
# 1376.6666666666667

# %%
df3_class0 = df3[df3.Churn==0]
df3_class1 = df3[df3.Churn==1]

# %%
df3_class0.shape, df3_class1.shape
# Out:
# ((7, 27), (3, 27))

# %%
df_train = pd.concat([df3_class0.sample(4130, replace=True), df3_class1])
df_train.Churn.value_counts()
# Out:
# Churn
# 0.0    4130
# 1.0       3
# Name: count, dtype: int64

# %%
def get_train_batch(df_majority, df_minority, start, end):
    df_train = pd.concat([df_majority[start:end], df_minority], axis=0)

    X_train = df_train.drop('Churn', axis='columns')
    y_train = df_train.Churn
    return X_train, y_train

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4000 - loss: 0.7158
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.7092
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6000 - loss: 0.7026
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7000 - loss: 0.6962
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7000 - loss: 0.6900
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7000 - loss: 0.6840
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7000 - loss: 0.6782
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7000 - loss: 0.6725
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7000 - loss: 0.6670
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7000 - loss: 0.6614
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7000 - loss: 0.6556
# Epoch 12/100
# ...

# %%
X_train, y_train = get_train_batch(df3_class0, df3_class1, 0, 1495)

y_pred1 = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.4000 - loss: 0.6920
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4000 - loss: 0.6850
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5000 - loss: 0.6779
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6000 - loss: 0.6708
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.6000 - loss: 0.6638
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6000 - loss: 0.6572
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6000 - loss: 0.6506
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.5000 - loss: 0.6441
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6000 - loss: 0.6375
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.6000 - loss: 0.6314
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6000 - loss: 0.6254
# Epoch 12/100
# ...

# %%
X_train, y_train = get_train_batch(df3_class0, df3_class1, 1495, 2990)

y_pred2 = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.5949
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.5785
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.5627
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.5472
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.5316
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.5160
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.5006
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.4854
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.4705
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.4558
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.4414
# Epoch 12/100
# ...

# %%
X_train, y_train = get_train_batch(df3_class0, df3_class1, 2990, 4130)

y_pred3 = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0000e+00 - loss: 0.8494
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.0000e+00 - loss: 0.8240
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.0000e+00 - loss: 0.7994
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.0000e+00 - loss: 0.7782
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3333 - loss: 0.7576
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.3333 - loss: 0.7370
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3333 - loss: 0.7169
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3333 - loss: 0.6974
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6667 - loss: 0.6793
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6667 - loss: 0.6631
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6667 - loss: 0.6480
# Epoch 12/100
# ...

# %%
len(y_pred1)
# Out:
# 3

# %%
y_pred_final = y_pred1.copy()
for i in range(len(y_pred1)):
    n_ones = y_pred1[i] + y_pred2[i] + y_pred3[i]
    if n_ones>1:
        y_pred_final[i] = 1
    else:
        y_pred_final[i] = 0

# %%
cl_rep = classification_report(y_test, y_pred_final)
print(cl_rep)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         2
#          1.0       0.33      1.00      0.50         1
#
#     accuracy                           0.33         3
#    macro avg       0.17      0.50      0.25         3
# weighted avg       0.11      0.33      0.17         3
